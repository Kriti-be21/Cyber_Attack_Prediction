# %% [markdown]
# <a href="https://colab.research.google.com/github/Kriti-be21/Cyber_Attack_Prediction/blob/main/Checkpoints/Plots_checkpoint.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score
from scipy.signal import butter, lfilter, freqz

train1 = pd.read_csv('/content/drive/MyDrive/train_dataset01.csv')
train2 = pd.read_csv('/content/drive/MyDrive/train_dataset02.csv')
test = pd.read_csv('/content/drive/MyDrive/test_dataset.csv')

# %%
numerics = train2.select_dtypes(include="float64")
means = numerics.mean()

for col in numerics.columns:
    fig, ax = plt.subplots(figsize=(20, 10))
    ax.plot(numerics[col])
    ax.set_ylabel(col)
    
    color = 'tab:red'
    plt.axhline(y=means[col], color=color)
    plt.show()
